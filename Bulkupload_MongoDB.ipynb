# %%
import pandas as pd
import pymongo
import json

# %%
'read the fitbitdata.csv and store the dataframe'
fitbit_df =pd.read_csv("F:\ineuron FSDS\pandas practice\Task 31-07-2022\FitBitdata.csv")

# %%
fitbit_df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
# The issue regarding bulk upload to mongoDB was that it was creating a single document inside our collection.
# So here the trick is while converting CSV to JSON we need to mention orient as records. Thats it. Each record will be
# a separate document in mondodb.

# %%
fitbit_df.to_json(r"F:\ineuron FSDS\pandas practice\Task 31-07-2022\new_FitBitdat.json",orient="records")

# %%
df_read_json = pd.read_json(r"F:\ineuron FSDS\pandas practice\Task 31-07-2022\new_FitBitdat.json")

# %%
df_read_json.head() # so the conversion is OK.
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
# load the JSON, and store it in data.
# P.S - the data here is stored as list, unlike dictionary if the JSON was not specified as records earlier.

with open(r"F:\ineuron FSDS\pandas practice\Task 31-07-2022\new_FitBitdat.json") as file:
    data = json.load(file)

# %%
data[0:5]  # the data stored in below format which we can now push to mongodb.
# Out:
# [{'Id': 1503960366,
#   'ActivityDate': '3/25/2016',
#   'TotalSteps': 11004,
#   'TotalDistance': 7.1100001335,
#   'TrackerDistance': 7.1100001335,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.5699999332,
#   'ModeratelyActiveDistance': 0.4600000083,
#   'LightActiveDistance': 4.0700001717,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 33,
#   'FairlyActiveMinutes': 12,
#   'LightlyActiveMinutes': 205,
#   'SedentaryMinutes': 804,
#   'Calories': 1819},
#  {'Id': 1503960366,
#   'ActivityDate': '3/26/2016',
#   'TotalSteps': 17609,
#   'TotalDistance': 11.5500001907,
#   'TrackerDistance': 11.5500001907,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 6.9200000763,
#   'ModeratelyActiveDistance': 0.7300000191,
#   'LightActiveDistance': 3.9100000858,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 89,
#   'FairlyActiveMinutes': 17,
#   'LightlyActiveMinutes': 274,
#   'SedentaryMinutes': 588,
#   'Calories': 2154},
# ...

# %%
#bulk upload to mongodb

client = pymongo.MongoClient("mongodb+srv://achowdh:failsafe@agnik0.mmtem.mongodb.net/?retryWrites=true&w=majority")
db = client.test

db = client['fitbit']
collection = db['newfitbitdata']
collection.insert_many(data)

# %%
#the above push was success. Lets try to fetch some collections from mongodb

# %%
record_ex1 = collection.find({"Id": 1503960366})

# %%
list_record =[]
for i in record_ex1:
    list_record.append(i)

# %%
list_record[:2]
# Out:
# [{'_id': ObjectId('62f9e63b010ed0fc641e4066'),
#   'Id': 1503960366,
#   'ActivityDate': '3/25/2016',
#   'TotalSteps': 11004,
#   'TotalDistance': 7.1100001335,
#   'TrackerDistance': 7.1100001335,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.5699999332,
#   'ModeratelyActiveDistance': 0.4600000083,
#   'LightActiveDistance': 4.0700001717,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 33,
#   'FairlyActiveMinutes': 12,
#   'LightlyActiveMinutes': 205,
#   'SedentaryMinutes': 804,
#   'Calories': 1819},
#  {'_id': ObjectId('62f9e63b010ed0fc641e4067'),
#   'Id': 1503960366,
#   'ActivityDate': '3/26/2016',
#   'TotalSteps': 17609,
#   'TotalDistance': 11.5500001907,
#   'TrackerDistance': 11.5500001907,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 6.9200000763,
#   'ModeratelyActiveDistance': 0.7300000191,
#   'LightActiveDistance': 3.9100000858,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 89,
# ...

# %%
df=pd.DataFrame(d) # convert the same to DataFrame

# %%
df
# Out:
#                          _id          Id ActivityDate  TotalSteps  \
# 0   62f9e63b010ed0fc641e4066  1503960366    3/25/2016       11004
# 1   62f9e63b010ed0fc641e4067  1503960366    3/26/2016       17609
# 2   62f9e63b010ed0fc641e4068  1503960366    3/27/2016       12736
# 3   62f9e63b010ed0fc641e4069  1503960366    3/28/2016       13231
# 4   62f9e63b010ed0fc641e406a  1503960366    3/29/2016       12041
# 5   62f9e63b010ed0fc641e406b  1503960366    3/30/2016       10970
# 6   62f9e63b010ed0fc641e406c  1503960366    3/31/2016       12256
# 7   62f9e63b010ed0fc641e406d  1503960366     4/1/2016       12262
# 8   62f9e63b010ed0fc641e406e  1503960366     4/2/2016       11248
# 9   62f9e63b010ed0fc641e406f  1503960366     4/3/2016       10016
# 10  62f9e63b010ed0fc641e4070  1503960366     4/4/2016       14557
# 11  62f9e63b010ed0fc641e4071  1503960366     4/5/2016       14844
# 12  62f9e63b010ed0fc641e4072  1503960366     4/6/2016       11974
# ...
